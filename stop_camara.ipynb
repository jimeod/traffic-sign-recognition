# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.9/175.9 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 105.9 MB/s eta 0:00:00

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="IjnprEMRpwqSGsgIsBtq")
project = rf.workspace("vision-por-computadora-7g2ez").project("stop_detection-j1jrv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Stop_Detection-1 in yolov8:: 100%|██████████| 2719/2719 [00:00<00:00, 11896.90it/s]

# %%
# !ls STOP-3 # este ya no lo corras
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
import os #este ya no lo corras

ruta = "/content/STOP-3/train"

imagenes = [f for f in os.listdir(ruta)
            if f.endswith(('.jpg', '.jpeg', '.png'))]

print("Total imágenes:", len(imagenes))
# Out:
# Total imágenes: 0

# %%
# !cat STOP-3/data.yaml #este no lo corras
# Out:
# names:
# - '3'
# - STOP_SIGN
# nc: 2
# roboflow:
#   license: CC BY 4.0
#   project: stop-y2yyn
#   url: https://universe.roboflow.com/vision-por-computadora-7g2ez/stop-y2yyn/dataset/3
#   version: 3
#   workspace: vision-por-computadora-7g2ez
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 79.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Stop-Detection-1/data.yaml",
    epochs=45,
    imgsz=416,
    batch=8,
    patience=7,
    workers=4,
    amp=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.35 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ##Luisito mi patron

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/Stop_Detection-1/data.yaml",
    epochs=80,
    imgsz=416,
    batch=16,
    patience=20,
    workers=4,
    amp=True,
    lr0=0.01,
    cos_lr=True,
    close_mosaic=10
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.36 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model("/content/stop-sign-along-country-road_Getty-680x402.jpg", conf=0.4)

annotated = results[0].plot()

cv2_imshow(annotated)
# Out:
# image 1/1 /content/stop-sign-along-country-road_Getty-680x402.jpg: 256x416 1 Stop_Detection, 148.4ms
# Speed: 3.7ms preprocess, 148.4ms inference, 4.0ms postprocess per image at shape (1, 3, 256, 416)
# <PIL.Image.Image image mode=RGB size=680x402>

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model("/content/img_1774379049.237.jpg", conf=0.4)

annotated = results[0].plot()

cv2_imshow(annotated)
# Out:
# image 1/1 /content/img_1774379049.237.jpg: 160x416 (no detections), 43.7ms
# Speed: 0.8ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 416)
# <PIL.Image.Image image mode=RGB size=420x150>

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model("/content/stop1.jpg", conf=0.4)

annotated = results[0].plot()

cv2_imshow(annotated)
# Out:
# image 1/1 /content/stop1.jpg: 160x416 1 Stop_Detection, 14.6ms
# Speed: 1.4ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 416)
# <PIL.Image.Image image mode=RGB size=420x150>

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model("/content/stop2.137.jpg", conf=0.4)

annotated = results[0].plot()

cv2_imshow(annotated)
# Out:
# image 1/1 /content/stop2.137.jpg: 160x416 1 Stop_Detection, 9.0ms
# Speed: 0.7ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 416)
# <PIL.Image.Image image mode=RGB size=420x150>

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model("/content/stop3.jpg", conf=0.4)

annotated = results[0].plot()

cv2_imshow(annotated)
# Out:
# image 1/1 /content/stop3.jpg: 160x416 (no detections), 8.2ms
# Speed: 0.7ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 416)
# <PIL.Image.Image image mode=RGB size=420x150>

# %%
model = YOLO("/content/runs/detect/train/weights/best.pt")
results = model("/content/stop4 .jpg", conf=0.4)

annotated = results[0].plot()

cv2_imshow(annotated)
# Out:
# image 1/1 /content/stop4 .jpg: 160x416 (no detections), 10.6ms
# Speed: 0.7ms preprocess, 10.6ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 416)
# <PIL.Image.Image image mode=RGB size=420x150>

# %%
from google.colab import files
files.download("/content/runs/detect/train/weights/best.pt")
